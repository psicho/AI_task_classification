# %% [markdown]
# ## Валидация задач по категориям Good/Agood/Bad

# %% [markdown]
# Загрузка необходимых библиотек и модулей

# %%
from tokenization import token
import pandas as pd

# %% [markdown]
# ## Входные данные
# Загрузите в поле url ссылку на файл в docs.google.com

# %%
url = 'https://docs.google.com/spreadsheets/d/1erY7TXYKzyUjYbsqhdOuP5XaI3m6bVIejxkRfdLZXd4/edit?usp=sharing'

# %%
token.classification_data_set(url)
# Out:
# Обработано 1 из 548 задач
# Обработано 2 из 548 задач
# Обработано 3 из 548 задач
# Обработано 4 из 548 задач
# Обработано 5 из 548 задач
# Обработано 6 из 548 задач
# Обработано 7 из 548 задач
# Обработано 8 из 548 задач
# Обработано 9 из 548 задач
# Обработано 10 из 548 задач
# Обработано 11 из 548 задач
# Обработано 12 из 548 задач
# Обработано 13 из 548 задач
# Обработано 14 из 548 задач
# Обработано 15 из 548 задач
# Обработано 16 из 548 задач
# Обработано 17 из 548 задач
# Обработано 18 из 548 задач
# Обработано 19 из 548 задач
# Обработано 20 из 548 задач
# Обработано 21 из 548 задач
# Обработано 22 из 548 задач
# Обработано 23 из 548 задач
# Обработано 24 из 548 задач
# Обработано 25 из 548 задач
# Обработано 26 из 548 задач
# Обработано 27 из 548 задач
# Обработано 28 из 548 задач
# Обработано 29 из 548 задач
# Обработано 30 из 548 задач
# Обработано 31 из 548 задач
# Обработано 32 из 548 задач
# Обработано 33 из 548 задач
# Обработано 34 из 548 задач
# ...

# %% [markdown]
# После окончания работы модуля итоговый файл можно найти в директории проекта: **Data/classification.csv**

# %%
data = pd.read_csv("Data/classification.csv")
print(data.shape)
data.head()
# Out:
# (548, 4)
#    Unnamed: 0                                           gen_text  \
# 0           4  If you have a rectangle with a length of 12 in...
# 1           5  If you have two circles with diameters that ar...
# 2           6  What is the perimeter of a triangle with sides...
# 3           9  The number of students in a class is 20. If th...
# 4          13  The sum of three consecutive even integers is ...
#
#   Good/Agood/Bad                        Group
# 0           good     Addition and subtraction
# 1           good  Multiplication and division
# 2            bad     Addition and subtraction
# 3           good  Multiplication and division
# 4            bad  Multiplication and division
